# %%
import cf
import jupyter_black

jupyter_black.load()
import cfplot as cfp
import netCDF4
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
file = (
    "/home/users/jonnyhtw/canari_gws/users/jonnyhtw/"
    "canari-CF-aggregation/priority-variables/CFA-files/"
    "CF-1.13_HIST2_CANARI_1_cv575_ATM_mon_m01s00i024_3.cfa"
)
fields = cf.read(file)
f = fields[0]
cfp.con(f[0].squeeze())
plt.show();
